# %% [markdown]
# Data and library import

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Import data
df = pd.read_csv('data.csv')
df.head()
# Out:
#                    Timestamp What is your gender?  \
# 0  2024/01/29 9:04:49 AM EST                 Male
# 1  2024/01/29 9:21:39 AM EST                 Male
# 2  2024/01/29 9:26:51 AM EST               Female
# 3  2024/01/29 9:36:21 AM EST    Prefer not to say
# 4  2024/01/29 9:37:31 AM EST                 Male
#
#   Of these, which is your age group? What is your class?  \
# 0                              21-30           Sophomore
# 1                              21-30              Senior
# 2                              21-30              Senior
# 3                              21-30              Senior
# 4                              11-20            Freshman
#
#   Do you floss your teeth? What do you mainly use to floss with?  \
# 0                      Yes                           Floss picks
# 1                      Yes                           Floss picks
# 2                      Yes                           Floss picks
# ...

# %%
gender = df.iloc[:, 1].value_counts()
plt.title('Distribution of Gender')
plt.pie(gender, labels=gender.index, autopct="%1.0F%%")

plt.show()

# %%
age = df.iloc[:, 2].value_counts()
plt.title('Distribution of Age Groups')
plt.pie(age, labels=age.index, autopct="%1.0F%%")

plt.show()

# %%
year = df.iloc[:, 3].value_counts()
plt.title('Distribution of Class Year')
plt.pie(year, labels=year.index, autopct="%1.0F%%")

plt.show()

# %%
floss = df.iloc[:, 4].value_counts()
plt.title('Distribution of Flossing')
plt.pie(floss, labels=floss.index, autopct="%1.0F%%")

plt.show()

# %%
flossMethod = df.iloc[:, 5].value_counts()
plt.title('Distribution of Floss Methods')
plt.pie(flossMethod, labels=flossMethod.index, autopct="%1.0F%%")

plt.show()

# %%
flossReasons = df.iloc[:, 6].value_counts()
plt.title('Distribution of Floss Reasons')
plt.pie(flossReasons, labels=flossReasons.index, autopct="%1.0F%%")

plt.show()

# %%
flossFreq = df.iloc[:, 7].value_counts()
plt.title('Distribution of Floss Frequency')
plt.pie(flossFreq, labels=flossFreq.index, autopct="%1.0F%%")

plt.show()

# %%
flossFreqReasons = df.iloc[:, 8].value_counts()
plt.title('Distribution of Floss Frequency Reasons')
plt.pie(flossFreqReasons, labels=flossFreqReasons.index, autopct="%1.0F%%")

plt.show()

# %%
flossLocations = df.iloc[:, 9].value_counts()
plt.title('Distribution of Floss Locations')
plt.pie(flossLocations, labels=flossLocations.index, autopct="%1.0F%%")

plt.show()

# %%
flossLocationsReasons = df.iloc[:, 10].value_counts()
plt.title('Distribution of Floss Location Reasons')
plt.pie(flossLocationsReasons, labels=flossLocationsReasons.index, autopct="%1.0F%%")

plt.show()
